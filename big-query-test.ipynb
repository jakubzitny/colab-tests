# %% [markdown]
# # Before you begin
#
#
# 1.   Use the [Cloud Resource Manager](https://console.cloud.google.com/cloud-resource-manager) to Create a Cloud Platform project if you do not already have one.
# 2.   [Enable billing](https://support.google.com/cloud/answer/6293499#enable-billing) for the project.
# 3.   [Enable BigQuery](https://console.cloud.google.com/flows/enableapi?apiid=bigquery) APIs for the project.

# %% [markdown]
# ### Provide your credentials to the runtime

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# # Use BigQuery via magics
#
# The `google.cloud.bigquery` library also includes a magic command which runs a query and displays the result, optionally saving it to a variable as a `DataFrame`.

# %%
# %%bigquery --project apitestx df
# SELECT
#   COUNT(*) as total_rows
# FROM `bigquery-public-data.samples.gsod`
#
# #SELECT * FROM `bigquery-public-data.github_repos.files` where path contains ".ttf" limit 1000
# Out:
#    total_rows
# 0   114420316

# %%
df = 1

# %%
# %%bigquery --project apitestx df
# SELECT * FROM `bigquery-public-data.github_repos.files` limit 1000
# Out:
#                                              repo_name                 ref  \
# 0                             abhisit/TechNexion-linux      refs/heads/alc
# 1                                      UCSD/now-mobile      refs/heads/dev
# 2                          tsukutabi/tsukutabi_for_web      refs/heads/dev
# 3                                 blrm/openshift-tools      refs/heads/stg
# 4                        OCA/account-invoice-reporting     refs/heads/11.0
# 5                                   invenfantasy/kolla     refs/heads/bcec
# 6                        nader-eloshaiker/cocos2d-objc     refs/heads/v3.4
# 7                       GroundZeroLinux/groundzero-iso     refs/heads/xfce
# 8                       GroundZeroLinux/groundzero-iso     refs/heads/xfce
# 9                       GroundZeroLinux/groundzero-iso     refs/heads/xfce
# 10                      GroundZeroLinux/groundzero-iso     refs/heads/xfce
# 11                      GroundZeroLinux/groundzero-iso     refs/heads/xfce
# 12                                       k0ste/ansible    refs/heads/devel
# 13                                     direvus/ansible    refs/heads/devel
# 14                                    jaddison/ansible    refs/heads/devel
# 15                                    ogenstad/ansible    refs/heads/devel
# 16                                   richardcs/ansible    refs/heads/devel
# 17                             inverse-inc/packetfence    refs/heads/devel
# 18                                          matwey/otp    refs/heads/maint
# 19                                      shizhai/wprobe   refs/heads/ar9344
# 20                                      shizhai/wprobe   refs/heads/ar9344
# 21                                      shizhai/wprobe   refs/heads/ar9344
# 22                             Hazelsuko07/17WarmingUp   refs/heads/hy_try
# 23                                             np/ling   refs/heads/master
# 24                                             np/ling   refs/heads/master
# 25                                            iegor/qt   refs/heads/master
# 26                                           LQJJ/demo   refs/heads/master
# 27                                           nglt/leya   refs/heads/master
# 28                                           wujf/qemu   refs/heads/master
# 29                                          Canar/meta   refs/heads/master
# ..                                                 ...                 ...
# 970        fedora-modularity/baseruntime-package-lists   refs/heads/master
# 971        wangdxnum1/MyOpenSourceCodeStudyAndResearch   refs/heads/master
# 972       atomicobject/rubymotion-nimbus-table-example   refs/heads/master
# 973       scentuals-natural-organic-skincare/scentuals   refs/heads/master
# 974      jmaris/Longhorn-Transformation-pack-for-Linux   refs/heads/master
# 975      sktjdgns1189/android_kernel_samsung_SHV-E220S   refs/heads/master
# 976     Faenza-NewVanilla/faenza-newvanilla-icon-theme   refs/heads/master
# 977     Faenza-NewVanilla/faenza-newvanilla-icon-theme   refs/heads/master
# 978     Faenza-NewVanilla/faenza-newvanilla-icon-theme   refs/heads/master
# 979     Faenza-NewVanilla/faenza-newvanilla-icon-theme   refs/heads/master
# 980     Faenza-NewVanilla/faenza-newvanilla-icon-theme   refs/heads/master
# 981     Faenza-NewVanilla/faenza-newvanilla-icon-theme   refs/heads/master
# 982  alex-friedl/crossplatform-push-notifications-e...   refs/heads/master
# 983  h4ck3rm1k3/federal-election-commission-aggrega...   refs/heads/master
# 984  h4ck3rm1k3/federal-election-commission-aggrega...   refs/heads/master
# 985  h4ck3rm1k3/federal-election-commission-aggrega...   refs/heads/master
# 986                        alanbuxey/freeradius-server   refs/heads/v4.0.x
# 987                                      taget/libvirt  refs/heads/cdp_v10
# 988                     lenovo-a3-dev/kernel_lenovo_a3  refs/heads/cm-11.0
# 989            gabry3795/android_device_huawei_mt7_l09  refs/heads/cm-13.0
# 990           GearCM/android_kernel_samsung_exynos5410  refs/heads/cm-13.0
# 991           eoghan2t9/android_kernel_asus_moorefield  refs/heads/cm-14.1
# 992                                   brodkinca/hubcap  refs/heads/develop
# 993                                   diging/vogon-web  refs/heads/develop
# 994                                 haka-security/haka  refs/heads/develop
# 995                                 swojtyna/starsview  refs/heads/develop
# 996                                CrazyKids/Scarecrow  refs/heads/develop
# 997                           chadsy/onebusaway-iphone  refs/heads/develop
# 998                        SHOmniAuth/SHOmniAuthFlickr  refs/heads/develop
# 999                     vovkasm/react-native-web-image  refs/heads/develop
#
#                                                   path   mode  \
# 0    tools/testing/selftests/powerpc/copyloops/memc...  40960
# 1    ios/Pods/Headers/Private/RNSVG/RNSVGCGFloatArr...  40960
# 2    app/webroot/node_modules/gulp/node_modules/gul...  40960
# 3    openshift/installer/vendored/openshift-ansible...  40960
# 4    setup/partner_time_to_pay/odoo/addons/partner_...  40960
# 5    docker/centos/binary/cinder-app/cinder-data/build  40960
# 6     cocos2d-tests-android/Headless/tests/ColorTest.m  40960
# 7    airootfs/etc/skel/.icons/Obsidian_gray/places/...  40960
# 8    airootfs/etc/skel/.themes/Arc-Polo/unity/unmax...  40960
# 9    airootfs/etc/skel/.icons/delorean_woken/DeLore...  40960
# 10   airootfs/etc/skel/.icons/Obsidian/apps/32/libr...  40960
# 11   airootfs/etc/skel/.icons/Obsidian/status/96/we...  40960
# 12   lib/ansible/modules/network/f5/_bigip_security...  40960
# 13     lib/ansible/modules/crypto/acme/_letsencrypt.py  40960
# 14                                  bin/ansible-galaxy  40960
# 15   lib/ansible/modules/cloud/ovirt/_ovirt_cluster...  40960
# 16                         test/runner/injector/pytest  40960
# 17                 debian/packetfence-pfdetect.service  40960
# 18   lib/inets/examples/httpd_load_test/hdlt_ssl_cl...  40960
# 19   build_dir/target-mips_r2_uClibc-0.9.33.2/libnc...  40960
# 20   build_dir/target-mips_r2_uClibc-0.9.33.2/linux...  40960
# 21   build_dir/target-mips_r2_uClibc-0.9.33.2/opens...  40960
# 22                    py3.6/lib/python2.7/posixpath.py  40960
# 23                   fixtures/sequence/mk_par2_prll.ll  40960
# 24          tests/failure/unused_chan.t/unused_chan.ll  40960
# 25                              include/qbuttongroup.h  40960
# 26   36admob/Pods/Headers/Public/Google-Mobile-Ads-...  40960
# 27   Funner-2/Pods/Headers/Public/GPUImage/GPUImage...  40960
# 28                                       roms/openbios  57344
# 29   root/libstdc++-v3/testsuite/25_algorithms/find...  40960
# ..                                                 ...    ...
# 970               data/Fedora/devel/hp/ppc64/hints.txt  40960
# 971  AFNetworkingStudy/Pods/Headers/Public/AFNetwor...  40960
# 972     vendor/Pods/BuildHeaders/Nimbus/NIDeviceInfo.h  40960
# 973  public_html/app/design/frontend/base/default/t...  40960
# 974                icons/Win2-7/actions/32/tab_new.png  40960
# 975                 Merge-Tool_4.2.x/ramdisk/sbin/nice  40960
# 976             Faenza/actions/scalable/text_under.svg  40960
# 977          Faenza-Darker/actions/96/gtk-zoom-100.png  40960
# 978           Faenza-Darker/actions/48/go-previous.png  40960
# 979  Faenza-Darker/actions/48/gtk-revert-to-saved-l...  40960
# 980    Faenza/devices/64/gnome-dev-printer-network.png  40960
# 981          Faenza-Darker/actions/22/gtk-redo-ltr.png  40960
# 982  app/ios/Pods/Headers/Private/React/React/RCTSu...  40960
# 983  index/PAYEE/STATE/CO/ZIP/801245461/CITY/Lone_T...  40960
# 984  index/ELECTION/CODE/G2010/2011/20110504/727399...  40960
# 985  index/ELECTION/CODE/G2010/2011/20110411/721738...  40960
# 986           src/tests/modules/sql_sqlite/auth.unlang  40960
# 987  tests/virhostcpudata/linux-subcores1/node/node...  40960
# 988  mediatek/config/a3000_row_wifi/android.hardwar...  40960
# 989  _useful/_imgs/extracted/twrp_recovery/recovery...  40960
# 990                   drivers/gpu/arm/mali400/ump/arch  40960
# 991  drivers/external_drivers/camera/drivers/media/...  40960
# 992  node_modules/grunt-contrib/node_modules/grunt/...  40960
# 993  annotations/static/annotations/bower_component...  40960
# 994     doc/test/workshop-blurring-the-web-attempt.lua  40960
# 995  StarsView/Pods/Headers/Public/Nocilla/LSHTTPBo...  40960
# 996   Pods/Headers/Private/Reachability/Reachability.h  40960
# 997  Pods/Headers/Private/GoogleAnalytics/GAIEcomme...  40960
# 998  Example/Pods/BuildHeaders/SHOmniAuthFlickr/SHO...  40960
# 999  tests/TestApp/Pods/Headers/Private/React/RCTMe...  40960
#
#                                            id  \
# 0    cce33fb6f9d8938b22372db810ff86980fc7bf56
# 1    cf0504a633949be89a18700b87d4531d61fee086
# 2    bb9cf7b16c064d9aa27ef624d5d245c9cee67fb1
# 3    20c4c58cfade12582ee1658a23dfc5239fd094fc
# 4    856432ed9502599e2903b8a17001cf0edda64ac2
# 5    ec19138031a79efca08ea540f84f25ef77ed2f22
# 6    e5a71c83948a938278b93381a1a42c0cc952d93a
# 7    406170cd893b4f2f1ef425d24147859980a1dbae
# 8    050eb913a072512f7a8ce1da942d670ec30a2a95
# 9    a509cbcf9599b5086aecc5c94710ea8b20c8f776
# 10   5fa0d28e2b7907ba4ec9971751618241e6a7df22
# 11   3429ba52153b469ad36e9a87389e53a1c33d5de5
# 12   a78176b5bf3a0ba5a689845d5fda40d6ca30fabf
# 13   3fdd4055b40b6806fbe50c9b2dce3225140a1756
# 14   cabb1f519aad06228924e7621ea30edd2b7af9d5
# 15   3ca1876e0d7a00d58d9bdef4731f752e25433f71
# 16   1f9d09cbf2a5816c7eb0086a0179005c0e064604
# 17   ce7d8dcc3b589d423954c79a8bd88536677a32c8
# 18   41644a1098aa08fa402e98df7722d49c29d0383d
# 19   20f67b5577026109d02928e7b1f00f072762df7b
# 20   29570eee61a92adec24029fcd01bdc396860a88f
# 21   31c87c38853dace5d58cfa70edf3380dd8cb04c9
# 22   cc89aa2fcad0d515fa275985e0af4cb58f25a61c
# 23   fb97b5581c34b7a49aa9045b2dbfa6fe4aee9cdf
# 24   6a982e626ba3d1bbac68af9e7a84ea63cb50a26b
# 25   db0e2135119ea5b0531eac917fd0af4478368e51
# 26   f5991977b894334150894f99a4441574734aa698
# 27   31810f65d1da2760a611849af764560871bccdcf
# 28   0f3d51ef22ec9166beb3ed434d253029ed7cfe84
# 29   c358b3a9c90d70cb1ae6f7fd3af7300ae17790c6
# ..                                        ...
# 970  93fd165b3fa10bf24a9ccef47878faf3f78e1ad4
# 971  67519d98485a322c76e9a749aab58171e7d4e142
# 972  dd19ef651e8c2a0ed3657219e0b7b41969dd386d
# 973  73eed988284629c22c9cdc088f21a773a34e2578
# 974  6fdf7705102d85d874caa7f08f5f3d210d97527d
# 975  c3fa810285e0144098a23067542ef14e2579181b
# 976  7090f907ced1642ca0f16e74a117a49a22fe2d0e
# 977  2f1996d4ae276d04a163e21ccd254ed07edb9e8f
# 978  0f29c3da34be2a1377ca4ee0f6f9d379f9879883
# 979  d69a834295d61c9155d08642c43bf043cc68d77f
# 980  8ce6074f48573cd08cf6244f89793f16908b85a5
# 981  9b89f67a94b1cc649755a72b6fb866b9ad43fa1d
# 982  7da0fa32df3e6b0586d9bc145c5e1475ed3b6ee6
# 983  a7a1556c37bd61af7cb83aa7131a49ab034f4872
# 984  ae1818207f3a4f0dbc47e927f10665b4fb4a4af0
# 985  dd45e98813f50e7bd3c447044d952abb26041b65
# 986  3ccd80eee6b4c8eebdcb3c426b27fabf6f973cff
# 987  22ba3c4f63f902b5aa7fc9e72d58405ada2293eb
# 988  8377bdc9bf670ac7556e0629b8706cf7446a3e01
# 989  c3fa810285e0144098a23067542ef14e2579181b
# 990  a65a3fc45ec223229d0b516437ebcd70973a314f
# 991  407a28ec8357c0c8ae8837ff1abe1f1643c3645d
# 992  f81f4e2354cf5ddc38e604df58827e839671d4d7
# 993  fbb7ee0eed8d1dd0fe3b5a9d6ff41d1c4f044675
# 994  3dc0adc271c5ab8bcc88450110f76bebae512c7c
# 995  5e331230aea9595771b4690adfc7d961ee816c01
# 996  a30e80c626cfb850409a2c095212e0771fb37447
# 997  67e0a87990eaf0289e05a54e44cd7ec9f8bdc23e
# 998  315e36e3e8dec43e86de52fdd7356e5e237fcad6
# 999  874425918664267c7d37ef4c74fca1fe272be5a8
#
#                                         symlink_target
# 0          ../../../../../arch/powerpc/lib/memcpy_64.S
# 1    ../../../../../node_modules/react-native-svg/i...
# 2                             ../dateformat/bin/cli.js
# 3                                       ../../../roles
# 4                      ../../../../partner_time_to_pay
# 5              ../../../../../tools/build-docker-image
# 6          ../../../cocos2d-ui-tests/tests/ColorTest.m
# 7                                      folder-home.png
# 8                window-buttons/maximize_unfocused.svg
# 9                       ../apps/drive-harddisk-usb.svg
# 10                                libreoffice-calc.png
# 11                             weather-clear-night.svg
# 12                         bigip_firewall_port_list.py
# 13                                 acme_certificate.py
# 14                                             ansible
# 15                              ovirt_cluster_facts.py
# 16                                         injector.py
# 17        ../conf/systemd/packetfence-pfdetect.service
# 18     ../../test/httpc_SUITE_data/ssl_client_cert.pem
# 19                                              ncsa-m
# 20                                   libip4tc.so.0.1.0
# 21                           ../../crypto/asn1/asn1t.h
# 22   /System/Library/Frameworks/Python.framework/Ve...
# 23                              ../all/mk_par2_prll.ll
# 24                ../../../fixtures/all/unused_chan.ll
# 25                       ../src/widgets/qbuttongroup.h
# 26   ../../../../Google-Mobile-Ads-SDK/Frameworks/f...
# 27   ../../../GPUImage/framework/Source/GPUImageVor...
# 28                                                None
# 29   ../../../../../../../gcc/libstdc++-v3/testsuit...
# ..                                                 ...
# 970                                ../common-hints.txt
# 971  ../../../AFNetworking/UIKit+AFNetworking/AFNet...
# 972       ../../Nimbus/src/overview/src/NIDeviceInfo.h
# 973  ../../../../../../../../../.modman/benz_theme/...
# 974                                        tab-new.png
# 975                                            busybox
# 976                        ./format-text-underline.svg
# 977        ../../../Faenza/actions/96/gtk-zoom-100.png
# 978    ../../../Faenza-Dark/actions/48/go-previous.png
# 979  ../../../Faenza/actions/48/gtk-revert-to-saved...
# 980                                      ./printer.png
# 981        ../../../Faenza/actions/22/gtk-redo-ltr.png
# 982  ../../../../../../node_modules/react-native/Re...
# 983  ../../../../../../../../../../../../../../../....
# 984  ../../../../../../../objects/ba/520f58b94a97c8...
# 985  ../../../../../../../objects/db/cc65899a646f4b...
# 986                                 ../sql/auth.unlang
# 987                                    ../../cpu/cpu83
# 988  ../mt8389_tablet_a3v2/android.hardware.bluetoo...
# 989                                            busybox
# 990                                  ./arch-orion-m400
# 991  ../../../atomisp_driver/hrt/hive_isp_css_mm_hrt.h
# 992                       ../deflate-js/bin/inflate.js
# 993                                     ../mime/cli.js
# 994      ../user/workshop/blurring-the-web-attempt.lua
# 995        ../../../Nocilla/Nocilla/Model/LSHTTPBody.h
# 996               ../../../Reachability/Reachability.h
# 997  ../../../GoogleAnalytics/Sources/GAIEcommerceP...
# 998    ../../../../SHOmniAuthFlickr/SHOmniAuthFlickr.h
# 999  ../../../../../../node_modules/react-native/Re...
#
# [1000 rows x 6 columns]

# %% [markdown]
# # Use BigQuery through google-cloud-bigquery
#
# See [BigQuery documentation](https://cloud.google.com/bigquery/docs) and [library reference documentation](https://googlecloudplatform.github.io/google-cloud-python/latest/bigquery/usage.html).
#
# The [GSOD sample table](https://bigquery.cloud.google.com/table/bigquery-public-data:samples.gsod) contains weather information collected by NOAA, such as precipitation amounts and wind speeds from late 1929 to early 2010.

# %% [markdown]
# ### Declare the Cloud project ID which will be used throughout this notebook

# %%
project_id = '[your project ID]'

# %% [markdown]
# ### Sample approximately 2000 random rows

# %%
from google.cloud import bigquery

client = bigquery.Client(project=project_id)

sample_count = 2000
row_count = client.query('''
  SELECT 
    COUNT(*) as total
  FROM `bigquery-public-data.samples.gsod`''').to_dataframe().total[0]

df = client.query('''
  SELECT
    *
  FROM
    `bigquery-public-data.samples.gsod`
  WHERE RAND() < %d/%d
''' % (sample_count, row_count)).to_dataframe()

print('Full dataset has %d rows' % row_count)
# Out:
# Full dataset has 114420316 rows

# %% [markdown]
# ### Describe the sampled data

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ea8415b8a3ee> in <module>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### View the first 10 rows

# %%
df.head(10)
# Out:
#    station_number  wban_number  year  month  day  mean_temp  \
# 0          596640        99999  1977      8   22  86.000000
# 1          265240        99999  1959      1   19  21.700001
# 2          260460        99999  1965      4   18  48.700001
# 3          404380        99999  1975     12   23  69.800003
# 4          102490        99999  1958      8   26  58.000000
# 5          865950        99999  1968      9    2  47.500000
# 6          915830        99999  1973      3   28  77.900002
# 7          262310        99999  1957      7   13  71.500000
# 8          915680        99999  2001      5   21  79.199997
# 9           62670        99999  1997     11    2  39.500000
#
#    num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 0                      4       77.400002                         4.0
# 1                      4       18.700001                         4.0
# 2                      4       27.799999                         4.0
# 3                      4       48.200001                         4.0
# 4                      4       55.500000                         4.0
# 5                      4       34.700001                         4.0
# 6                      4       69.800003                         4.0
# 7                      4       60.500000                         4.0
# 8                      4       69.800003                         4.0
# 9                      4       38.900002                         4.0
#
#    mean_sealevel_pressure   ...     min_temperature  min_temperature_explicit  \
# 0             1001.799988   ...                None                      None
# 1             1014.799988   ...                None                      None
# 2             1010.700012   ...                None                      None
# 3             1017.099976   ...                None                      None
# 4             1011.400024   ...                None                      None
# 5             1023.700012   ...                None                      None
# 6             1011.500000   ...                None                      None
# 7             1018.200012   ...                None                      None
# 8             1012.500000   ...                None                      None
# 9                     NaN   ...                None                      None
#
#    total_precipitation  snow_depth    fog   rain   snow   hail  thunder  \
# 0                 0.00         NaN  False  False  False  False    False
# 1                  NaN         NaN  False  False  False  False    False
# 2                 0.00         NaN  False  False  False  False    False
# 3                 0.00         NaN  False  False  False  False    False
# 4                 0.16         NaN   True   True   True   True     True
# 5                 0.04         NaN  False  False  False  False    False
# 6                  NaN         NaN  False  False  False  False    False
# 7                 0.02         NaN  False  False  False  False    False
# 8                 0.00         NaN  False  False  False  False    False
# 9                 0.16         NaN  False  False  False  False    False
#
#    tornado
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
#
# [10 rows x 31 columns]

# %%
# 10 highest total_precipitation samples
df.sort_values('total_precipitation', ascending=False).head(10)[['station_number', 'year', 'month', 'day', 'total_precipitation']]
# Out:
#       station_number  year  month  day  total_precipitation
# 285           377400  1982     10    2                11.18
# 1215          107630  1977      8   26                10.08
# 420           586660  1978      9   12                 6.34
# 1853          102000  2000      5    9                 5.91
# 141           235780  1965      7    5                 5.91
# 1448          983280  1978      6   11                 3.48
# 311           332750  1959     10   28                 2.95
# 60            578830  1994      6   15                 2.60
# 1314          729580  1973      5   24                 2.36
# 660           313460  1973      7   19                 1.85

# %% [markdown]
# # Use BigQuery through pandas-gbq
#
# The `pandas-gbq` library is a community led project by the pandas community. It covers basic functionality, such as writing a DataFrame to BigQuery and running a query, but as a third-party library it may not handle all BigQuery features or use cases.
#
# [Pandas GBQ Documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_gbq.html)

# %%
import pandas as pd

sample_count = 2000
df = pd.io.gbq.read_gbq('''
  SELECT name, SUM(number) as count
  FROM `bigquery-public-data.usa_names.usa_1910_2013`
  WHERE state = 'TX'
  GROUP BY name
  ORDER BY count DESC
  LIMIT 100
''', project_id=project_id, verbose=False, dialect='standard')

df.head()
# Out:
#       name   count
# 0    James  272793
# 1     John  235139
# 2  Michael  225320
# 3   Robert  220399
# 4    David  219028
